# %% [markdown]
# ### GDP assignment

# %% [markdown]
# ### 1.Load the Data

# %%
import pandas as pd # importing the library so that we can use it

# %%
gdpData = pd.read_csv('GDP (nominal) per Capita.csv')

# %%
gdpData
# Out:
#      Unnamed: 0 Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 0             1            Monaco    Europe             0         0
# 1             2     Liechtenstein    Europe             0         0
# 2             3        Luxembourg    Europe        132372      2023
# 3             4           Ireland    Europe        114581      2023
# 4             5           Bermuda  Americas             0         0
# ..          ...               ...       ...           ...       ...
# 218         219            Malawi    Africa           496      2023
# 219         220       South Sudan    Africa           467      2023
# 220         221      Sierra Leone    Africa           415      2023
# 221         222       Afghanistan      Asia           611      2020
# 222         223           Burundi    Africa           249      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 0                234316            2021       234317    2021
# ...

# %% [markdown]
# ### 2.Display the First  and Last 3 Rows

# %%
gdpData.head(3) # print top 3 rows
# Out:
#    Unnamed: 0 Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 0           1            Monaco    Europe             0         0
# 1           2     Liechtenstein    Europe             0         0
# 2           3        Luxembourg    Europe        132372      2023
#
#    WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 0              234316            2021       234317    2021
# 1              157755            2020       169260    2021
# 2              133590            2021       133745    2021

# %%
gdpData.tail(3) # print the last 3 rows
# Out:
#      Unnamed: 0 Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 220         221      Sierra Leone    Africa           415      2023
# 221         222       Afghanistan      Asia           611      2020
# 222         223           Burundi    Africa           249      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 220                 480            2021          505    2021
# 221                 369            2021          373    2021
# 222                 222            2021          311    2021

# %% [markdown]
# ### 3.Display the dimensions of the data set

# %%
gdpData.shape
# Out:
# (223, 9)

# %% [markdown]
# ### 4.Display Information about the DataFrame

# %%
gdpData.info() # print summary description of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          223 non-null    int64
#  1   Country/Territory   223 non-null    object
#  2   UN_Region           223 non-null    object
#  3   IMF_Estimate        223 non-null    int64
#  4   IMF_Year            223 non-null    int64
#  5   WorldBank_Estimate  223 non-null    int64
#  6   WorldBank_Year      223 non-null    int64
#  7   UN_Estimate         223 non-null    int64
#  8   UN_Year             223 non-null    object
# dtypes: int64(6), object(3)
# memory usage: 15.8+ KB

# %% [markdown]
# ### 5. Subset Using loc

# %%
#gdpData.loc[5:8,"Country/Territory", "IMF_Estimate", "UN_Year"]
gdpData.loc[5,"Country/Territory"] # display subset of the data number and integer
# Out:
# 'Norway'

# %% [markdown]
# ### 6. Subset Using iloc

# %%
# display subset of the WorldBank_Estimate column 7th row 
# gdpData.iloc[3:8,5:10] gdpData.iloc[3:8,[1,3,6]
gdpData.iloc[7, 5]
# Out:
# 72794

# %% [markdown]
# ### 7. Conditional Subsetting

# %%
# Select rows where the IMF_Estimate is greater than 100.
#IMF_Estimate_Greater100 = gdpData[gdpData['IMF_Estimate']>100]

# %%
imfOver100 = gdpData[(gdpData['IMF_Estimate'] > 100)]
imfOver100
# Out:
#      Unnamed: 0 Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 2             3        Luxembourg    Europe        132372      2023
# 3             4           Ireland    Europe        114581      2023
# 5             6            Norway    Europe        101103      2023
# 6             7       Switzerland    Europe         98767      2023
# 7             8         Singapore      Asia         91100      2023
# ..          ...               ...       ...           ...       ...
# 218         219            Malawi    Africa           496      2023
# 219         220       South Sudan    Africa           467      2023
# 220         221      Sierra Leone    Africa           415      2023
# 221         222       Afghanistan      Asia           611      2020
# 222         223           Burundi    Africa           249      2023
#
#      WorldBank_Estimate  WorldBank_Year  UN_Estimate UN_Year
# 2                133590            2021       133745    2021
# ...

# %%
# Select rows where the WorldBank_Estimate is less than 50.
# WorldBank_Estimat_Less50 = gdpData[(gdpData['WorldBank_Estimate'] < 50)]

# %%
worldbankOver100 = gdpData[(gdpData['WorldBank_Estimate'] < 50)]
worldbankOver100
worldbankOver100.shape
# Out:
# (7, 9)

# %%
# Select rows where the UN_Estimate is between 75 and 150.Series.between(start, end, inclusive=True)
# UN_Estimate_75To150 = gdpData[(gdpData["UN_Estimate"]>75)&(gdpData["UN_Estimate"]<150)]

# %%
unBetween75and150 = gdpData[(gdpData.UN_Estimate.between(75, 150))]
unBetween75and150
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Country/Territory, UN_Region, IMF_Estimate, IMF_Year, WorldBank_Estimate, WorldBank_Year, UN_Estimate, UN_Year]
# Index: []

# %% [markdown]
# ### 8. Summary Statistics

# %%
stats = round(gdpData[['IMF_Estimate', 'WorldBank_Estimate', 'UN_Estimate']].describe(),2) 
print(stats)
# Generate summary statistics for numerical columns (IMF_Estimate, WorldBank_Estimate, UN_Estimate).
# Out:
#         IMF_Estimate  WorldBank_Estimate    UN_Estimate
# count     223.000000          223.000000     223.000000
# mean    15351.632287        18927.417040   17767.304933
# std     22550.899445        29103.564915   28698.104167
# min         0.000000            0.000000       0.000000
# 25%      1406.500000         2273.500000    2039.000000
# 50%      5421.000000         6805.000000    6396.000000
# 75%     19697.000000        23715.000000   20740.000000
# max    132372.000000       234316.000000  234317.000000

# %% [markdown]
# ### 9. Analyse based on nonnumeric column

# %%
# Count the number of countries in each UN region
noOfCountriesByReg = gdpData.groupby(['UN_Region']).size()#.sort_values(ascending=False)\
display(noOfCountriesByReg)
#noOfCountriesByReg = gdpData.groupby(['UN_Region']).size().sort_values(ascending=False)\
#.reset_index(name="country/Teritory")

gdpData.UN_Regeon.value_counts()
# Out:
# UN_Region
# Africa      55
# Americas    48
# Asia        51
# Europe      48
# Oceania     20
# World        1
# dtype: int64

# %%
# Create subsets for the following UN regions

# %%
# Africa – Call this subset GDP_Africa
GDP_Africa = gdpData[(gdpData['UN_Region'] == 'Africa')] 
GDP_Africa
# Out:
#      Unnamed: 0         Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 73           74                Seychelles    Africa         19536      2023
# 100         101                 Mauritius    Africa         11548      2023
# 106         107         Equatorial Guinea    Africa          9777      2023
# 109         110                     Gabon    Africa          9294      2023
# 118         119                  Botswana    Africa          7270      2023
# 121         122                     Libya    Africa          6763      2023
# 124         125              South Africa    Africa          6485      2023
# 138         139                   Namibia    Africa          5100      2023
# 143         144                   Algeria    Africa          4481      2023
# 147         148                Cape Verde    Africa          4278      2023
# 149         150                  Eswatini    Africa          4146      2023
# ...

# %%
# Europe – Call this subset GDP_Europe

# %%
GDP_Europe = gdpData[(gdpData['UN_Region'] == 'Europe')] 
GDP_Europe
# GDP_Europe = gdpData[(gdpData['UN_Region'] == 'Europe')].describe()
# Out:
#      Unnamed: 0       Country/Territory UN_Region  IMF_Estimate  IMF_Year  \
# 0             1                  Monaco    Europe             0         0
# 1             2           Liechtenstein    Europe             0         0
# 2             3              Luxembourg    Europe        132372      2023
# 3             4                 Ireland    Europe        114581      2023
# 5             6                  Norway    Europe        101103      2023
# 6             7             Switzerland    Europe         98767      2023
# 8             9             Isle of Man    Europe             0         0
# 12           13                 Iceland    Europe         75180      2023
# 13           14         Channel Islands    Europe             0         0
# 14           15           Faroe Islands    Europe             0         0
# 15           16                 Denmark    Europe         68827      2023
# 17           18             Netherlands    Europe         61098      2023
# ...

# %%
# Create summary statistics for the above two regions and compare. 
# Write short paragraphs to describe your findings. Feel free to make any assumptions. 
#summary_AfricaAndEurope = gdpData[GDP_Africa, GDP_Europe].describe()
#summary_AfricaAndEurope = gdpData[(gdpData['UN_Region'] == 'Africa') & (gdpData['UN_Region'] == 'Europe')].describe()
#summary_AfricaAndEurope
#gdpData[["UN_Region == 'Africa'", "UN_Region == 'Europe'"]].describe()
#gdpData.groupby('UN_Region').describe(include=['Africa','Europe'])

gdpData.groupby('UN_Region').describe()
# IMF and UN Estimate are significantly high in Europe than Africa.
# Out:
#           Unnamed: 0                                                      \
#                count        mean        std   min     25%    50%     75%
# UN_Region
# Africa          55.0  178.818182  35.501743  74.0  156.50  188.0  206.50
# Americas        48.0   89.479167  43.648007   5.0   65.75   87.0  121.75
# Asia            51.0  119.764706  62.873711   8.0   55.50  129.0  172.00
# Europe          48.0   52.687500  40.319024   1.0   19.50   46.0   75.75
# Oceania         20.0  105.800000  51.032085  17.0   68.50  115.0  146.25
# World            1.0   93.000000        NaN  93.0   93.00   93.0   93.00
#
#                  IMF_Estimate                ... WorldBank_Year          \
#              max        count          mean  ...            75%     max
# UN_Region                                    ...
# Africa     223.0         55.0   2802.345455  ...         2021.0  2021.0
# Americas   177.0         48.0  11871.041667  ...         2021.0  2021.0
# ...

# %%
avgmark = round(studentData.mark.mean(), 2) # print avarage value of numeric column
avgmark

# %% [markdown]
# ### 10. Conclusion

# %%
# Write a brief conclusion based on your observations. Mention any interesting patterns or trends you notice in the data. 
# Discuss any further steps or questions that arose during the analysis.
